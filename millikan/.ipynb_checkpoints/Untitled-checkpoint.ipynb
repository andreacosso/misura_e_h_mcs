// %% [markdown]
// analisi dati millikan

// %%
ifstream file("milikan.dat");

auto histo = new TH1D("histo","millikan",65,0.,0.);
auto c = new TCanvas();

double k = 0;
while(file >> k){
    histo->Fill(k);
}

c->Draw();
c->cd();
histo->Draw();

 
auto f = new TF1("f","[2]*TMath::Gaus(x,[0],[1]) + [3]*TMath::Gaus(x,2*[0],[1]) + [4]*TMath::Gaus(x,3*[0],[1])",0.,6.3);
f->SetParameter(0,1.602);
//f->SetParLimits(0,1.59,1.6025);
f->SetParameter(1,0.2);
f->SetParameter(2,0.4);
f->SetParameter(3,0.4);
f->SetParameter(4,0.4);
histo->Fit("f","LR");
//histo->Fit("gaus","","",0.,6.2);
// Out:
//  FCN=21.8005 FROM MIGRAD    STATUS=CONVERGED     309 CALLS         310 TOTAL
//                      EDM=2.65696e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  p0           1.65669e+00   2.70891e-02   8.71213e-05  -2.35968e-03
//    2  p1           4.34081e-01   4.23816e-02   1.06306e-04   1.19193e-02
//    3  p2           3.79442e+00   9.30379e-01   2.82392e-03   2.26655e-04
//    4  p3           4.54164e+00   1.06662e+00   3.14961e-03  -1.52098e-04
//    5  p4           5.61679e+00   1.20598e+00   3.43845e-03   1.19431e-04
//                                ERR DEF= 0.5
// Warning in <TROOT::Append>: Replacing existing TH1: histo (Potential memory leak).

// %%
if(abs())
